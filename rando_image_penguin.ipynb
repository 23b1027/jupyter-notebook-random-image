# %%
import cv2
import matplotlib.pyplot as plt

# 画像を読み込む（input.jpg が同じフォルダに必要）
img = cv2.imread('doubutu_penguin.png')

# がウシアンブラー
filtered = cv2.GaussianBlur(img, (9, 9), 0)

# フィルタリング前後の画像を並べてたい
fig, axes = plt.subplots(1, 2, figsize=(8, 4))
axes[0].imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
axes[0].set_title('Before')
axes[0].axis('off')
axes[1].imshow(cv2.cvtColor(filtered, cv2.COLOR_BGR2RGB))
axes[1].set_title('After')
axes[1].axis('off')
plt.show()

# %%
pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\23b1027\anaconda3\lib\site-packages (from opencv-python) (1.26.4)
# Downloading opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl (39.5 MB)
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#    - -------------------------------------- 1.0/39.5 MB 5.6 MB/s eta 0:00:07
#    -- ------------------------------------- 2.4/39.5 MB 6.4 MB/s eta 0:00:06
#    --- ------------------------------------ 3.7/39.5 MB 5.9 MB/s eta 0:00:07
#    ---- ----------------------------------- 4.7/39.5 MB 5.9 MB/s eta 0:00:06
#    ------ --------------------------------- 6.0/39.5 MB 5.9 MB/s eta 0:00:06
#    ------- -------------------------------- 7.3/39.5 MB 6.0 MB/s eta 0:00:06
#    -------- ------------------------------- 8.7/39.5 MB 6.2 MB/s eta 0:00:05
#    ---------- ----------------------------- 10.0/39.5 MB 6.2 MB/s eta 0:00:05
#    ----------- ---------------------------- 11.5/39.5 MB 6.3 MB/s eta 0:00:05
#    ------------- -------------------------- 13.1/39.5 MB 6.4 MB/s eta 0:00:05
#    -------------- ------------------------- 14.4/39.5 MB 6.5 MB/s eta 0:00:04
#    ---------------- ----------------------- 16.0/39.5 MB 6.5 MB/s eta 0:00:04
#    ------------------ --------------------- 17.8/39.5 MB 6.7 MB/s eta 0:00:04
#    ------------------- -------------------- 19.1/39.5 MB 6.7 MB/s eta 0:00:04
#    -------------------- ------------------- 20.7/39.5 MB 6.7 MB/s eta 0:00:03
#    ---------------------- ----------------- 21.8/39.5 MB 6.6 MB/s eta 0:00:03
#    ----------------------- ---------------- 23.1/39.5 MB 6.6 MB/s eta 0:00:03
#    ------------------------ --------------- 24.6/39.5 MB 6.6 MB/s eta 0:00:03
#    -------------------------- ------------- 26.0/39.5 MB 6.6 MB/s eta 0:00:03
#    --------------------------- ------------ 27.3/39.5 MB 6.6 MB/s eta 0:00:02
#    ---------------------------- ----------- 28.6/39.5 MB 6.5 MB/s eta 0:00:02
#    ------------------------------ --------- 29.9/39.5 MB 6.6 MB/s eta 0:00:02
#    ------------------------------- -------- 30.7/39.5 MB 6.4 MB/s eta 0:00:02
#    -------------------------------- ------- 31.7/39.5 MB 6.4 MB/s eta 0:00:02
#    -------------------------------- ------- 32.5/39.5 MB 6.3 MB/s eta 0:00:02
#    --------------------------------- ------ 33.6/39.5 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 34.3/39.5 MB 6.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 34.9/39.5 MB 6.0 MB/s eta 0:00:01
#    ------------------------------------ --- 35.7/39.5 MB 5.9 MB/s eta 0:00:01
#    ------------------------------------- -- 37.0/39.5 MB 5.9 MB/s eta 0:00:01
#    -------------------------------------- - 38.3/39.5 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------------  39.3/39.5 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------------- 39.5/39.5 MB 5.9 MB/s eta 0:00:00
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.11.0.86
# Note: you may need to restart the kernel to use updated packages.
